# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamsartape/Netflix-Movies-and-TV-Shows-Clustering/blob/main/Temp_Netflix_Movies_and_TV_Shows_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**- **Netflix Movies and TVshows Clustering**

# %% [markdown]
# **Project Type**- Unsupervised
#
# **Contribution**
# 1. Name-Charan C S
#
#    Email- ccharancs543@gmail.com
#
#    contribution- Collab Notebook,Summary
# 2. Name-Saraswat Mukherjee
#
#    Email- mae21saraswat@gmail.com
#
#    Contribution- Technical documentation
# 3. Name- Lokesh Tokas
#
#    Email- lokesh.you@gmail.com
#
#    Contribution- Summary
# 4. Name-Shubham Sartape
#
#    Email- shubhamns19.pumba@gmail.com
#
#    Contribution- Presentation

# %% [markdown]
# #**Github**

# %% [markdown]
# https://github.com/charann90/Netflix-Movies-and-TV-Shows-Clustering.git

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In this project we have implemented clustering analysis based on similar text content of Netflix movies and Tv shows clustering dataset. We will be understanding the shows that are similar to and different from one another by creating clusters, which may be an advantage to offer the consumers personalized show suggestions depending on their preferences. The goal of this project is to group the Netflix shows into certain clusters such that the shows/movies within a cluster are similar to each other and the shows in different clusters are dissimilar to each other.
#
# The given data set contains 7787 entries and 12 columns which have both numerical continuous values and text features. Data cleaning is done for the five features which have null values, to correct those missing values both dropping and replacing is done for those features.
#
# In data pre-processing and feature engineering part different functions like removing stop words, Stemming, Lemmatization and Tokenization techniques are used to convert the text columns to vectorized features TF-IDF is used to determine which terms are most discriminative and relevant for a particular document or set of documents, compared to the rest of the corpus. To find the most important features (also called principal components) that explain the maximum variance in the data principal component analysis is also used. Different clustering algorithms models are used to obtain high accuracy and conclusion is made on the basis of the best Machine Learning algorithm.
#
# In EDA, analysis is done to know the type of content available in different countries. Visualizing top countries with highest movies/Tv shows releases. Analysing the growth of contents released yearly. Concluding the monthly releases for both movies and tv shows. Analysing the content type with respect to the duration and plotting the distribution graph for the duration. Observing most occurring categories for the movies and tv shows and finding out the most popular rating for the content. Obtaining the largely repeated words and plotting them by using count vectorizer.
#
# In K-Means clustering model optimal clusters are obtained by elbow method and to test the quality of the clusters silhouette score is used. By hierarchical clustering optimal clusters are known by plotting dendrograms. We also used the DBSCAN plot to check the purity of the cluster.
#
# In k-Means clustering the silhouette score is highest for 2 clusters and the score is 0.510. The silhouette score for hierarchical cluster is highest for cluster 2 and the silhouette score is 0.505. By applying k-Means and hierarchical we got the best clusters and optimal clusters equal to 2.

# %% [markdown]
# # Problem Statement

# %% [markdown]
# This dataset consists of tv shows and movies available on Netflix as of 2019. The dataset is collected from Flixable which is a third-party Netflix search engine.
#
# In 2018, they released an interesting report which shows that the number of TV shows on Netflix has nearly tripled since 2010. The streaming service’s number of movies has decreased by more than 2,000 titles since 2010, while its number of TV shows has nearly tripled. It will be interesting to explore what all other insights can be obtained from the same dataset.
#
# Integrating this dataset with other external datasets such as IMDB ratings, rotten tomatoes can also provide many interesting findings.
#
# **In this project, you are required to do**
#
#
#
#
# *   Exploratory Data Analysis
#
# *   Understanding what type content is available in different countries
#
# *   Has Netflix increasingly focused on TV as compared to movies in recent years?
# *   Clustering similar content by matching text-based features

# %% [markdown]
# **Data Description**

# %% [markdown]
# ![Screenshot_20221222_094324.png](data:image/png;base64,...)

# %% [markdown]
# # Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('punkt')
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
import string
from sklearn.metrics import silhouette_samples
import matplotlib.cm as cm
from sklearn.cluster import DBSCAN
import scipy.cluster.hierarchy as shc
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Data uploading

# %%
#uploading and reading the data
df=pd.read_csv('https://raw.githubusercontent.com/shubhamsartape/Netflix-Movies-and-TV-Shows-Clustering/main/NETFLIX%20MOVIES%20AND%20TV%20SHOWS%20CLUSTERING.csv')
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# # Data Understanding

# %%
#getting the summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
#understanding the statistical information
df.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %% [markdown]
# # Data Cleaning

# %%
#checking the null values
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# The dataset contains a considerable number of null values across several columns, including director (2389), cast (718), country (507), date_added (10), and rating (7). Therefore, it is necessary to handle these null values to ensure data completeness and accuracy.

# %%
#dropping and replacing null valuse for different columns

#dropping null values of date_added and rating column as it has only single digit null values
df.dropna(subset=['date_added','rating'],inplace=True)
#replacing null values in director column by unknown
df['director'].fillna('unknown',inplace=True)
#replacing null values in country column by mode value of it
df['country'].fillna(df['country'].mode()[0],inplace=True)
#replacing null values in cast column by no cast
df['cast'].fillna('no cast',inplace=True)

# %%
#dropping unnessasary columns
df.drop(['show_id'],axis=1,inplace=True)

# %%
#checking null values after cleaning
df.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# After Data cleaning no null values are present.

# %% [markdown]
# # EDA

# %% [markdown]
# ## ***Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# Type of content available in different countries:

# %%
#count of type of content present in diffrent countries
df['type'].value_counts()
# Out:
# Movie      5372
# TV Show    2398
# Name: type, dtype: int64

# %% [markdown]
# We can see that movie content is double the number of TV shows

# %%
import seaborn as sns

# %%
#plotting the type of content in the form of pie plot
plt.figure(figsize=(6,7))
plt.pie(df['type'].value_counts(),labels=['movies','Tv Shows'],autopct='%1.0f%%')
plt.title('Type of content')
plt.legend()
plt.show()

# %% [markdown]
# * There are 69% of movie content and 31% of Tv show content on netflix

# %%
#replacing and converting datatype of duration column to integer

df['duration']=df['duration'].str.replace('Season','')
df['duration']=df['duration'].str.replace('s','')

# %%
#Replacing and converting datatype of duration column to integer
df['duration']=df['duration'].str.replace('min','')

df['duration']=df['duration'].astype(str).astype(int)

# %%
#creating a variable column for each type seperately
tv_shows=df[df['type']=='TV Show']
movie=df[df['type']=='Movie']

# %%
#count of movie and tv shows for different countries
df['country'].value_counts()
# Out:
# United States                                                   3051
# India                                                            923
# United Kingdom                                                   396
# Japan                                                            224
# South Korea                                                      183
#                                                                 ...
# Russia, United States, China                                       1
# Italy, Switzerland, France, Germany                                1
# United States, United Kingdom, Canada                              1
# United States, United Kingdom, Japan                               1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Name: country, Length: 681, dtype: int64

# %%
#percentage of ovreall share of movie/tvshow content for the top 10 countries 
df['country'].value_counts().nlargest(10).sum()/len(df)*100
# Out:
# 69.54954954954955

# %% [markdown]
# *   Content of top 10 countries accounts for 69.54% for overall contents present

# %%
#crreating a movie variable for seperated type of content grouping with countries
country_movie=pd.DataFrame(movie.groupby(['country'])['type'].size().sort_values(ascending=False))

# %%
#renaming the column
country_movie.rename(columns={'type':'count'})
# Out:
#                     count
# country
# United States        2076
# India                 852
# United Kingdom        193
# Canada                118
# Spain                  89
# ...                   ...
# India, Switzerland      1
# India, Pakistan         1
# India, Nepal            1
# India, Mexico           1
# Zimbabwe                1
#
# [590 rows x 1 columns]

# %%
#plotting movie counts of top countries
country_movie.head(10).plot(kind='bar',figsize=(10,8),title='top countries with highest movie releases',color='b',ylabel='movie count')

# %% [markdown]
# **United Nations has highest movie content released and then followed by India**

# %%
#creating a tvshow  variable for seperated tv shows type of content grouping with countries

country_tvshow=pd.DataFrame(tv_shows.groupby(['country'])['type'].size().sort_values(ascending=False))

# %%
#renaming the column
country_tvshow.rename(columns={'type':'count'})
# Out:
#                                 count
# country
# United States                     975
# United Kingdom                    203
# Japan                             155
# South Korea                       147
# India                              71
# ...                               ...
# Mexico, Spain                       1
# China, Hong Kong                    1
# Mauritius, South Africa             1
# Malaysia, Singapore, Hong Kong      1
# Uruguay, Germany                    1
#
# [183 rows x 1 columns]

# %%
#plotting tv show counts of top countries
country_tvshow.head(10).plot(kind='bar',figsize=(10,8),title='top countries with highest tv shows releases',color='b',ylabel='tv shows count')

# %% [markdown]
#  **United Nations has highest tv show content released and then followed by United Kingdom**
#
#
#
#
#
# ---

# %%
#listing all the numerical columns
num_col=['show_id','type','title','director','cast','country','date_added','release_year','rating','duration','listed_in','description']

# %%
#comparing type of content in different years
release_df=df.groupby(['release_year','type'])['release_year'].count().unstack()

# %%
release_df.tail(10)
# Out:
# type          Movie  TV Show
# release_year
# 2012          158.0     60.0
# 2013          202.0     63.0
# 2014          244.0     90.0
# 2015          380.0    156.0
# 2016          642.0    239.0
# 2017          742.0    268.0
# 2018          734.0    386.0
# 2019          582.0    414.0
# 2020          411.0    457.0
# 2021           12.0     19.0

# %%
#plotting sum of contentent released in different years
release_df.plot(figsize=(10,9),grid=True)
plt.title('Growth of content released yearly')
plt.ylabel('number of releases')
plt.xlabel('Release year ')
# Out:
# Text(0.5, 0, 'Release year ')

# %% [markdown]
# *   Netflix started releasing movies after 1940 and after 1980 Tv show content was started streaming.
# *   we can see that there is a graduall increase in releases after 2000 where movie content releases are more then Tv show content
# *  The number of movies is increasing at a faster rate compared to TV shows.
# *  Additionally, there was a considerable rise in the number of movies and TV episodes added to the platform after 2015.
# *  However, there has been a significant decline in the production of both movies and TV episodes after 2020.

# %%
#creating seperate columns for month and year from release date column
df['month']=pd.DatetimeIndex(df['date_added']).month
df['year']=pd.DatetimeIndex(df['date_added']).year
df.drop(['release_year'],axis=1,inplace=True)

# %%
#plotting monthly content released for both movies and Tv shows
plt.figure(figsize=(10,8))
sns.countplot(x='month',hue='type',data=df,palette="Accent")

# %% [markdown]
# *   It is concluded that in the month of january, october and december maximum
# movies/tvshows has been released.

# %% [markdown]
# **Top Movie/TV Show content type with respect to duration**

# %%
#plotting distribution plot for duration to see the frequency distribution 
plt.figure(figsize=(10,8))
sns.distplot(df['duration'],bins=30)
plt.title('length distribution of movies',fontsize=15)
# Out:
# Text(0.5, 1.0, 'length distribution of movies')

# %% [markdown]
# The mean duration of movies is 100 minutes

# %%
#creating a table for movies with highest duration
long_movies=movie[['title','duration']]
long_movies.sort_values(by=['duration'],ascending=False)
# Out:
#                                                  title  duration
# 957                         Black Mirror: Bandersnatch       312
# 6850                            The School of Mischief       253
# 4490                                    No Longer kids       237
# 3694                                Lock Your Girls In       233
# 5108                                   Raya and Sakina       230
# ...                                                ...       ...
# 463   American Factory: A Conversation with the Obamas        10
# 1203                                            Canvas         9
# 1501                                  Cops and Robbers         8
# 5694                                       Sol Levante         5
# 5605                                            Silent         3
#
# [5372 rows x 2 columns]

# %% [markdown]
# *   Black Mirror: Bandersnatch	is the longest movie which is 312 minutes long and the second is The School of Mischief	.

# %%
#creating a table for Tv shows with highest duration
long_tv_shows=tv_shows[['title','duration']]
long_tv_shows.sort_values(by=['duration'],ascending=False)
# Out:
#                                                   title  duration
# 2538                                     Grey's Anatomy        16
# 5912                                       Supernatural        15
# 4438                                               NCIS        15
# 1471                             COMEDIANS of the world        13
# 1537                                     Criminal Minds        12
# ...                                                 ...       ...
# 3563  Learning Songs by Little Baby Bum: Nursery Rhy...         1
# 3550                                 Laws of Attraction         1
# 3548                                           Lavender         1
# 610                                             Atelier         1
# 7785                              Zumbo's Just Desserts         1
#
# [2398 rows x 2 columns]

# %% [markdown]
# *  Grey's Anatomy		is longest Tv show which has 16 seasons and followed by Supernatural which has 15 seasons

# %% [markdown]
# **Most occured Categories for movies and Tv shows**

# %%
#top categories of movies
plt.figure(figsize=(12,10))
sns.countplot(y=movie['listed_in'],data=df,order=movie['listed_in'].value_counts().index[:15])

# %% [markdown]
# *   Movies which are documentaries and stand up comedy has highest content in netflix

# %%
#top categories of Tv shows
plt.figure(figsize=(12,10))
sns.countplot(y=tv_shows['listed_in'],data=df,order=tv_shows['listed_in'].value_counts().index[:15])

# %% [markdown]
# *   Tv shows for kids category has highest content in netflix

# %% [markdown]
# **Most popular ratings for Tvshows/Movies**

# %%
#plotting top movie content rating 
plt.figure(figsize=(12,10))
sns.countplot(df['rating'])

# %% [markdown]
# *   Most of the contents got rating TV_MA(Mature Audience) and the second most rated contents is for Tv-14(excludes children)

# %%
df.head(5)
# Out:
#       type  title           director  \
# 0  TV Show     3%            unknown
# 1    Movie   7:19  Jorge Michel Grau
# 2    Movie  23:59       Gilbert Chan
# 3    Movie      9        Shane Acker
# 4    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added rating  duration  \
# 0    August 14, 2020  TV-MA         4
# 1  December 23, 2016  TV-MA        93
# 2  December 20, 2018      R        78
# 3  November 16, 2017  PG-13        80
# 4    January 1, 2020  PG-13       123
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description  month  year
# 0  In a future where the elite inhabit an island ...      8  2020
# 1  After a devastating earthquake hits Mexico Cit...     12  2016
# 2  When an army recruit is found dead, his fellow...     12  2018
# 3  In a postapocalyptic world, rag-doll robots hi...     11  2017
# 4  A brilliant group of students become card-coun...      1  2020

# %%
df.shape
# Out:
# (7770, 12)

# %%
#merging all the text columns
df['clustered_data']=(df['title']+' '+df['listed_in']+' '+df['cast']+' '+df['description'])
#clustered_df.set_index('title',inplace=True)
df.head()
# Out:
#       type  title           director  \
# 0  TV Show     3%            unknown
# 1    Movie   7:19  Jorge Michel Grau
# 2    Movie  23:59       Gilbert Chan
# 3    Movie      9        Shane Acker
# 4    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added rating  duration  \
# 0    August 14, 2020  TV-MA         4
# 1  December 23, 2016  TV-MA        93
# 2  December 20, 2018      R        78
# 3  November 16, 2017  PG-13        80
# 4    January 1, 2020  PG-13       123
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description  month  year  \
# 0  In a future where the elite inhabit an island ...      8  2020
# 1  After a devastating earthquake hits Mexico Cit...     12  2016
# 2  When an army recruit is found dead, his fellow...     12  2018
# 3  In a postapocalyptic world, rag-doll robots hi...     11  2017
# 4  A brilliant group of students become card-coun...      1  2020
#
#                                       clustered_data
# 0  3% International TV Shows, TV Dramas, TV Sci-F...
# 1  7:19 Dramas, International Movies Demián Bichi...
# 2  23:59 Horror Movies, International Movies Tedd...
# 3  9 Action & Adventure, Independent Movies, Sci-...
# 4  21 Dramas Jim Sturgess, Kevin Spacey, Kate Bos...

# %%
df['clustered_data'][8]
# Out:
# "706 Horror Movies, International Movies Divya Dutta, Atul Kulkarni, Mohan Agashe, Anupam Shyam, Raayo S. Bakhirta, Yashvit Sancheti, Greeva Kansara, Archan Trivedi, Rajiv Pathak When a doctor goes missing, his psychiatrist wife treats the bizarre medical condition of a psychic patient, who knows much more than he's leading on."

# %% [markdown]
# # Feature Engineering and data preprocessing

# %% [markdown]
# **Removing punctuations for the text column**

# %%
#removing punctuations from the clustered data
def remove_punctuations(text):
  translator=str.maketrans('','',string.punctuation)
  return text.translate(translator)
df['clustered_data']=df['clustered_data'].apply(remove_punctuations)

# %%
df['clustered_data']
# Out:
# 0       3 International TV Shows TV Dramas TV SciFi  F...
# 1       719 Dramas International Movies Demián Bichir ...
# 2       2359 Horror Movies International Movies Tedd C...
# 3       9 Action  Adventure Independent Movies SciFi  ...
# 4       21 Dramas Jim Sturgess Kevin Spacey Kate Boswo...
#                               ...
# 7782    Zozo Dramas International Movies Imad Creidi A...
# 7783    Zubaan Dramas International Movies Music  Musi...
# 7784    Zulu Man in Japan Documentaries International ...
# 7785    Zumbos Just Desserts International TV Shows Re...
# 7786    ZZ TOP THAT LITTLE OL BAND FROM TEXAS Document...
# Name: clustered_data, Length: 7770, dtype: object

# %% [markdown]
# **Removing stop words**

# %%
#removing all thne stopwords from the clustered data
sw = nltk.corpus.stopwords.words('english')
def stopword(txt):
  description=[word.lower() for word in txt.split() if word.lower() not in sw]
  return ' '.join(description)

df['clustered_data']=df['clustered_data'].apply(stopword)

# %% [markdown]
# The removal of stopwords can help to reduce the size of the text corpus, and also improve the accuracy and efficiency of downstream tasks such as text classification

# %%
df['clustered_data']
# Out:
# 0       3 international tv shows tv dramas tv scifi fa...
# 1       719 dramas international movies demián bichir ...
# 2       2359 horror movies international movies tedd c...
# 3       9 action adventure independent movies scifi fa...
# 4       21 dramas jim sturgess kevin spacey kate boswo...
#                               ...
# 7782    zozo dramas international movies imad creidi a...
# 7783    zubaan dramas international movies music music...
# 7784    zulu man japan documentaries international mov...
# 7785    zumbos desserts international tv shows reality...
# 7786    zz top little ol band texas documentaries musi...
# Name: clustered_data, Length: 7770, dtype: object

# %% [markdown]
# **Stemming**

# %%
#stemming all the text data for  better understanding 
stemmer = SnowballStemmer('english')
def stemming(text):
  stemmer = SnowballStemmer('english')
  description=[stemmer.stem(word) for word in text.split()]

  return ' '.join(description)

df['clustered_data']=df['clustered_data'].apply(stemming)

# %% [markdown]
# This is a common preprocessing step that can help to reduce the number of unique words in a text corpus and improve the efficiency of downstream tasks such as text classification

# %% [markdown]
# **Tokenizing the data**

# %%
#calling a function to give token values for each word in a sentence
def tokenizer(text):
  word_tokens=word_tokenize(text)
  return word_tokens

df['clustered_data']=df['clustered_data'].apply(tokenizer)

# %% [markdown]
# Tokenizing is the process of breaking up a text into smaller units called tokens, such as words or subwords, to facilitate further analysis and processing

# %% [markdown]
# **Lemmatization**

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
#defining a function to lammatize the words
def lemma(txt):
    lemma=WordNetLemmatizer()
    description=[lemma.lemmatize(word) for word in txt]
    x=" ".join(description)
    return x
#applying the function    
df['clustered_data']=df['clustered_data'].apply(lemma)

# %% [markdown]
# Lemmatization is a technique that involves reducing words to their base or dictionary form, called a lemma, in order to improve text analysis and processing.

# %%
#deleting all the numbers
import re

def numb(txt):
  text=re.sub(r'[0-9]+', '', txt)
  return text

df['clustered_data']=df['clustered_data'].apply(numb)

# %%
from wordcloud import WordCloud
#generating the word cloud for the text data
wordcloud=WordCloud(background_color = 'black',width = 1200,height = 700).generate(str(df['clustered_data']))

plt.figure(figsize=(12,15))
plt.imshow(wordcloud)
plt.title('word cloud',fontsize=20)
# Out:
# Text(0.5, 1.0, 'word cloud')

# %% [markdown]
# **Getting Frequency of each word by applying countvectorizer**

# %% [markdown]
# CountVectorizer is a technique used to convert a collection of text documents into a matrix of token counts. After applying CountVectorizer, we can obtain the frequency of each word in the text corpus.

# %%
#defining function for word frequency count
count_vectorizer=CountVectorizer()
cv=count_vectorizer.fit(df['clustered_data'])


dictionary=cv.vocabulary_.items()

# %%
dictionary
# Out:
# dict_items([('intern', 17379), ('tv', 38513), ('show', 34128), ('drama', 10239), ('scifi', 32982), ('fantasi', 12013), ('joão', 18634), ('miguel', 24317), ('bianca', 4222), ('comparato', 7710), ('michel', 24246), ('gome', 14166), ('rodolfo', 31436), ('valent', 39177), ('vaneza', 39248), ('oliveira', 27169), ('rafael', 30095), ('lozano', 22107), ('vivian', 39787), ('porto', 29256), ('mel', 23941), ('fronckowiak', 13028), ('sergio', 33396), ('mamberti', 22813), ('zezé', 41758), ('motta', 25159), ('celso', 6424), ('frateschi', 12913), ('futur', 13192), ('elit', 10987), ('inhabit', 17271), ('island', 17572), ('paradis', 27984), ('far', 12023), ('crowd', 8334), ('slum', 34716), ('get', 13725), ('one', 27260), ('chanc', 6593), ('join', 18477), ('save', 32732), ('squalor', 35386), ('movi', 25201), ('demián', 9214), ('bichir', 4238), ('héctor', 16797), ('bonilla', 4800), ('oscar', 27448), ('serrano', 33416), ('azalia', 2873), ('ortiz', 27435), ('octavio', 26915), ('carmen', 6139), ('beato', 3651), ('devast', 9420), ('earthquak', 10619), ('hit', 16150), ('mexico', 24203), ('citi', 7327), ('trap', 38154), ('survivor', 36302), ('walk', 40008), ('life', 21563), ('wait', 39973), ('rescu', 30940), ('tri', 38214), ('desper', 9366), ('stay', 35552), ('aliv', 1091), ('horror', 16410), ('tedd', 37097), ('chan', 6590), ('stella', 35598), ('chung', 7229), ('henley', 15808), ('hii', 16020), ('lawrenc', 21182), ('koh', 20150), ('tommi', 37893), ('kuan', 20499), ('josh', 18595), ('lai', 20860), ('mark', 23176), ('lee', 21277), ('susan', 36307), ('leong', 21405), ('benjamin', 3896), ('lim', 21616), ('armi', 2182), ('recruit', 30660), ('found', 12831), ('dead', 8933), ('fellow', 12264), ('soldier', 34929), ('forc', 12754), ('confront', 7795), ('terrifi', 37260), ('secret', 33090), ('that', 37387), ('haunt', 15511), ('jungl', 18731), ('train', 38122), ('camp', 5929), ('action', 287), ('adventur', 472), ('independ', 17155), ('elijah', 10972), ('wood', 40736), ('john', 18461), ('reilli', 30767), ('jennif', 18175), ('connelli', 7816), ('christoph', 7183), ('plummer', 29042), ('crispin', 8276), ('glover', 14035), ('martin', 23256), ('landau', 20960), ('fred', 12924), ('tatascior', 36998), ('alan', 896), ('oppenheim', 27341), ('tom', 37869), ('kane', 19087), ('postapocalypt', 29278), ('world', 40784), ('ragdol', 30110), ('robot', 31384), ('hide', 15963), ('fear', 12196), ('danger', 8725), ('machin', 22378), ('extermin', 11808), ('brave', 5145), ('newcom', 26202), ('group', 14577), ('jim', 18317), ('sturgess', 35872), ('kevin', 19656), ('spacey', 35197), ('kate', 19326), ('bosworth', 4935), ('aaron', 46), ('yoo', 41320), ('liza', 21769), ('lapira', 21016), ('jacob', 17735), ('pitt', 28946), ('laurenc', 21129), ('fishburn', 12519), ('jack', 17723), ('mcgee', 23699), ('gad', 13242), ('sam', 32298), ('golzari', 14162), ('helen', 15738), ('carey', 6100), ('gilpin', 13879), ('brilliant', 5280), ('student', 35851), ('becom', 3695), ('cardcount', 6064), ('expert', 11777), ('intent', 17365), ('swindl', 36458), ('million', 24409), ('la', 20769), ('vega', 39362), ('casino', 6247), ('play', 29000), ('blackjack', 4482), ('mysteri', 25517), ('erdal', 11377), ('beşikçioğlu', 4106), ('yasemin', 41079), ('allen', 1136), ('meli', 23953), ('birkan', 4399), ('saygın', 32787), ('soysal', 35185), ('berkan', 3976), ('şal', 42103), ('metin', 24185), ('belgin', 3794), ('ayça', 2861), ('eren', 11387), ('selin', 33243), ('uludoğan', 38700), ('özay', 42039), ('fecht', 12211), ('suna', 36123), ('yıldızoğlu', 41563), ('genet', 13634), ('professor', 29614), ('experi', 11774), ('treatment', 38181), ('comatos', 7657), ('sister', 34521), ('blend', 4546), ('medic', 23852), ('shaman', 33658), ('cure', 8449), ('unlock', 38870), ('shock', 34064), ('side', 34282), ('effect', 10761), ('amina', 1432), ('khalil', 19685), ('ahm', 642), ('dawood', 8898), ('tarek', 36952), ('lotfi', 22008), ('el', 10887), ('fishawi', 12516), ('mahmoud', 22601), ('hijazi', 16023), ('jihan', 18306), ('asmaa', 2408), ('g ...

# %%
#creating a list of word and it's count value in a the form of a dataframe
word=[]
count=[]
for value, key in dictionary:
  word.append(value)
  count.append(key)

# %%
#Dataframe which is sorted by their value count
freq_df=pd.DataFrame({'word':word,'count':count}).sort_values(by='count',ascending=False)
freq_df
# Out:
#              word  count
# 25283          탄생  42146
# 25280        최강전사  42145
# 24533         잡는다  42144
# 25282         영웅의  42143
# 24532         반드시  42142
# ...           ...    ...
# 25135     aadarsh      4
# 34329  aacharekar      3
# 41290      aachal      2
# 39675       aabha      1
# 32550          aa      0
#
# [42147 rows x 2 columns]

# %% [markdown]
# These are the list of the total frequency of each word in the entire corpus.

# %%
top_words=freq_df.head(20)

# %%
#plotting the top 20 words which is largely repeated
top_words.plot(kind='bar',x='word',y='count',figsize=(15,10),color = plt.cm.summer(np.linspace(0, 1, 20)))

# %% [markdown]
# # TFIDF (Term Frequency-Inverse Document Frequency)

# %% [markdown]
# TF-IDF stands for "Term Frequency-Inverse Document Frequency." It is a numerical statistic used to evaluate the importance of a term within a document or a corpus of documents. TF-IDF takes into account the frequency of a term within a document (TF) and the frequency of the term within the entire corpus of documents (IDF). The idea behind TF-IDF is that words that occur frequently within a document but rarely in the corpus are likely to be important for that specific document. Conversely, words that occur frequently in the corpus but less frequently in a particular document are less likely to be significant for that document.

# %%
#creating the object for tfid vectoriser
tfid=TfidfVectorizer(stop_words='english',lowercase=False,max_features=5000)
x_tfid=tfid.fit_transform(df['clustered_data'])

# %%
x_tfid
# Out:
# <7770x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 177878 stored elements in Compressed Sparse Row format>

# %%
#converting the metrix into array
x=x_tfid.toarray()

# %%
#calling all the feature names
tfid.get_feature_names()
# Out:
# ['aamir',
#  'aaron',
#  'abandon',
#  'abbi',
#  'abbott',
#  'abdel',
#  'abduct',
#  'abdullah',
#  'abe',
#  'abel',
#  'abhay',
#  'abhishek',
#  'abigail',
#  'abil',
#  'aboard',
#  'abou',
#  'abraham',
#  'abroad',
#  'absurd',
#  'abu',
#  'abus',
#  'academi',
#  'accept',
#  'access',
#  'accid',
#  'accident',
#  'acclaim',
#  'accompani',
#  'account',
#  'accus',
#  'achiev',
#  'acosta',
#  'act',
#  'action',
#  'actionpack',
#  'activ',
#  'activist',
#  'actor',
#  'actress',
#  'actual',
#  'ad',
#  'ada',
#  'adam',
#  'adapt',
#  'addict',
#  'adebayo',
#  'adel',
#  'adesua',
#  'adil',
#  'aditi',
#  'aditya',
#  'adjust',
#  'adkin',
#  'adnan',
#  'adolesc',
#  'adopt',
#  'ador',
#  'adrian',
#  'adriana',
#  'adriano',
#  'adrienn',
#  'adrián',
#  'adult',
#  'adulthood',
#  'adventur',
#  'advic',
#  'affair',
#  'affect',
#  'affleck',
#  'afghanistan',
#  'afloat',
#  'africa',
#  'african',
#  'aftermath',
#  'age',
#  'agenc',
#  'agent',
#  'ago',
#  'agre',
#  'ahead',
#  'ahm',
#  'ahmad',
#  'ahmet',
#  'ahn',
#  'ai',
#  'aid',
#  'aida',
#  'aidan',
#  'ail',
#  'aim',
#  'aime',
#  'air',
#  'aishwarya',
#  'aj',
#  'ajay',
#  'akbar',
#  'akbağ',
#  'akhtar',
#  'aki',
#  'akio',
#  'akira',
#  'akshay',
#  'al',
#  'alaa',
#  'alain',
#  'alan',
#  'alazraqui',
#  'alba',
#  'albert',
#  'alberto',
#  'album',
#  'alcohol',
#  'alec',
#  'alejandra',
#  'alejandro',
#  'alessandro',
#  'alex',
#  'alexa',
#  'alexand',
#  'alexandra',
#  'alexi',
#  'alfonso',
#  'alfr',
#  'ali',
#  'alia',
#  'alic',
#  'alicia',
#  'alien',
#  'alina',
#  'alison',
#  'aliv',
#  'allan',
#  'alleg',
#  'allen',
#  'alli',
#  'allianc',
#  'allison',
#  'allow',
#  'alok',
#  'alon',
#  'alonso',
#  'alonzo',
#  'alter',
#  'altern',
#  'alvin',
#  'alway',
#  'alyson',
#  'alyssa',
#  'aman',
#  'amanda',
#  'amar',
#  'amateur',
#  'amaz',
#  'amber',
#  'ambit',
#  'ambiti',
#  'amel',
#  'amer',
#  'america',
#  'american',
#  'ami',
#  'amid',
#  'amin',
#  'amir',
#  'amit',
#  'amitabh',
#  'amr',
#  'amrish',
#  'amrita',
#  'ana',
#  'anand',
#  'anang',
#  'ancient',
#  'ander',
#  'anderson',
#  'andi',
#  'andr',
#  'andrea',
#  'andrew',
#  'andrzej',
#  'andré',
#  'angel',
#  'angela',
#  'anger',
#  'angi',
#  'angri',
#  'angus',
#  'anil',
#  'anim',
#  'anita',
#  'anjali',
#  'anmol',
#  'ann',
#  'anna',
#  'annabell',
#  'annett',
#  'anni',
#  'anniversari',
#  'announc',
#  'anonym',
#  'anoth',
#  'ansari',
#  'anson',
#  'answer',
#  'antholog',
#  'anthoni',
#  'antic',
#  'antoin',
#  'anton',
#  'antoni',
#  'antonia',
#  'antonio',
#  'anupam',
#  'anushka',
#  'anya',
#  'anyon',
#  'anyth',
#  'aoi',
#  'apart',
#  'apocalyps',
#  'apollo',
#  'app',
#  'appear',
#  'approach',
#  'april',
#  'apt',
#  'aqui',
#  'aquino',
#  'arai',
#  'arc',
#  'architect',
#  'archiv',
#  'arctic',
#  'area',
#  'arena',
#  'argentin',
#  'argentina',
#  'ari',
#  'aria',
#  'ariana',
#  'ariel',
#  'aristocrat',
#  'arjun',
#  'arm',
#  'armi',
#  'armisen',
#  'armor',
#  'armstrong',
#  'arnett',
#  'arnold',
#  'arora',
#  'arquett',
#  'arrang',
#  'arrest',
#  'arriv',
#  'arrog',
#  'arshad',
#  'art',
#  'arthur',
#  'artifact',
#  'artist',
#  'arturo',
#  'arun',
#  'arya',
#  'ash',
#  'asha',
#  'ashish',
#  'ashleigh',
#  'ashley',
#  'ashok',
#  'ashraf',
#  'ashton',
#  'ashwin',
#  'asia',
#  'ask',
#  'aspect',
#  'aspir',
#  'asrani',
#  'assassin',
#  'assault',
#  'assembl',
#  'assign',
#  'assist',
#  'assum',
#  'astin',
#  'athlet',
#  'atkin',
#  'atkinson',
#  'atsushi',
#  'attack',
#  'attempt',
#  'attenborough',
#  'attend',
#  'attent',
#  'attorney',
#  'attract',
#  'atul',
#  'aubrey',
#  'audienc',
#  'audrey',
#  'audu',
#  'august',
#  'aunt',
#  'aur',
#  'austin',
#  'australia',
#  'australian',
#  'author',
#  'autism',
#  'ava',
#  'aveng',
#  'averi',
#  'avoid',
#  'aw',
#  'await',
#  'awaken',
#  'awardwin',
#  'away',
#  'awkward',
#  'awri',
#  'aya',
#  'ayesha',
#  'ayo',
#  'ayten',
#  'azim',
#  'aziz',
#  'azmi',
#  'baba',
#  'babbar',
#  'babi',
#  'babu',
#  'babysitt',
#  'bachchan',
#  'bachelor',
#  'background',
#  'bacon',
#  'bad',
#  'bader',
#  'bae',
#  'baffl',
#  'bag',
#  'bahl',
#  'bai',
#  'bailey',
#  'bajpaye',
#  'bajwa',
#  'bake',
#  'baker',
#  'balan',
#  'balanc',
#  'baldwin',
#  'bale',
#  'ball',
#  'ballet',
#  'bamford',
#  'band',
#  'bandera',
#  'banerje',
#  'bang',
#  'bangkok',
#  'bank',
#  'bar',
#  'barbara',
#  'barber',
#  'barbi',
#  'bare',
#  'barn',
#  'baron',
#  'barr',
#  'barrett',
#  'barri',
#  'bartlam',
#  'baruchel',
#  'base',
#  'basebal',
#  'basketbal',
#  'baskın',
#  'basu',
#  'bate',
#  'bateman',
#  'battl',
#  'bautista',
#  'bay',
#  'bayoumi',
#  'bea',
#  'beach',
#  'beal',
#  'bean',
#  'bear',
#  'beast',
#  'beat',
#  'beatriz',
#  'beau',
#  'beauti',
#  'becam',
#  'becki',
#  'becom',
#  'bedi',
#  'bee',
#  'beer',
#  'befriend',
#  'begin',
#  'behavior',
#  'behindthescen',
#  'beirut',
#  'belief',
#  'believ',
#  'bell',
#  'bella',
#  'bello',
#  'belong',
#  'belov',
#  'belén',
#  'ben',
#  'beneath',
#  'benedict',
#  'benefit',
#  'benjamin',
#  'benji',
#  'bennett',
#  'benni',
#  'benoît',
#  'benson',
#  'bent',
#  'bentley',
#  'berger',
#  'berlin',
#  'bernal',
#  'bernard',
#  'bernardo',
#  'berni',
#  'berri',
#  'bert',
#  'best',
#  'bestsel',
#  'bet',
#  'beth',
#  'bethani',
#  'betray',
#  'bettani',
#  'better',
#  'betti',
#  'bever',
#  'bharadhwaj',
#  'bharat',
#  'bhardwaj',
#  'bhatia',
#  'bhatt',
#  'bhattacharya',
#  'bhave',
#  'bheem',
#  'bhimani',
#  'bianca',
#  'bibi',
#  'bichir',
#  'bicker',
#  'bid',
#  'big',
#  'biggest',
#  'bilgin',
#  'billi',
#  'billionair',
#  'bimbo',
#  'bin',
#  'biolog',
#  'biopic',
#  'bipasha',
#  'birbiglia',
#  'bird',
#  'birth',
#  'birthday',
#  'bishop',
#  'biswa',
#  'bit',
#  'bitter',
#  'bizarr',
#  'bj',
#  'björn',
#  'black',
#  'blackmail',
#  'blade',
#  'blair',
#  'blake',
#  'blanca',
#  'blanchett',
#  'blanco',
#  'blend',
#  'bless',
#  'blind',
#  'bliss',
#  'block',
#  'blockbust',
#  'blood',
#  'bloodi',
#  'bloom',
#  'blossom',
#  'blow',
#  'blue',
#  'blum',
#  'bn',
#  'bo',
#  'board',
#  'bob',
#  'bobbi',
#  'bodi',
#  'bodyguard',
#  'bold',
#  'bollywood',
#  'boman',
#  'bomb',
#  'bon',
#  'bond',
#  'bonham',
#  'bonnevill',
#  'bonni',
#  'book',
#  'boon',
#  'boot',
#  'booth',
#  'border',
#  'bore',
#  'borg',
#  'bori',
#  'born',
#  'bos',
#  'bosch',
#  'bose',
#  'boundari',
#  'bounti',
#  'bowen',
#  'bowl',
#  'box',
#  'boxer',
#  'boy',
#  'boyd',
#  'boyfriend',
#  'brad',
#  'bradi',
#  'bradley',
#  'braga',
#  'brain',
#  'brand',
#  'brandon',
#  'bratt',
#  'brave',
#  'brazil',
#  'brazilian',
#  'break',
#  'breakup',
#  'brendan',
#  'brennan',
#  'brent',
#  'brett',
#  'brian',
#  'bride',
#  'bridg',
#  'bridget',
#  'brie',
#  'bright',
#  'brijendra',
#  'brilliant',
#  'bring',
#  'britain',
#  'british',
#  'britt',
#  'brittani',
#  'brittney',
#  'broadbent',
#  'broadway',
#  'brodi',
#  'broke',
#  'broken',
#  'brook',
#  'brooklyn',
#  'brosnan',
#  'brother',
#  'brought',
#  'brown',
#  'bruce',
#  'bruno',
#  'brutal',
#  'bryan',
#  'bryant',
#  'bryce',
#  'bubbl',
#  'buck',
#  'buckley',
#  'bud',
#  'buddi',
#  'bueno',
#  'build',
#  'built',
#  'bulli',
#  'bumbl',
#  'burcu',
#  'bure',
#  'burgess',
#  'buri',
#  'burk',
#  'burn',
#  'burr',
#  'burt',
#  'burton',
#  'bus',
#  'buscemi',
#  'busi',
#  'businessman',
#  'buteau',
#  'butler',
#  'butt',
#  'buy',
#  'byer',
#  'byrn',
#  'bárbara',
#  'ca',
#  'caan',
#  'cabin',
#  'cage',
#  'cain',
#  'cairo',
#  'caitlin',
#  'caleb',
#  'california',
#  'callan',
#  'cam',
#  'came',
#  'camera',
#  'cameron',
#  'camila',
#  'camill',
#  'camp',
#  'campaign',
#  'campbel',
#  'campus',
#  'canada',
#  'canadian',
#  'cancer',
#  'candi',
#  'candid',
#  'capit',
#  'captain',
#  'captiv',
#  'captur',
#  'car',
#  'cara',
#  'card',
#  'care',
#  'career',
#  'carefre',
#  'carel',
#  'carey',
#  'carl',
#  'carla',
#  'carlo',
#  'carlson',
#  'carmen',
#  'carol',
#  'carolin',
#  'carolina',
#  'carr',
#  'carri',
#  'carrol',
#  'carson',
#  'cartel',
#  'carter',
#  'cartoonist',
#  'casa',
#  'casablanc',
#  'case',
#  'casey',
#  'cash',
#  'casino',
#  'cassandra',
#  'cassidi',
#  'cast',
#  'castillo',
#  'castl',
#  'castro',
#  'cat',
#  'catastroph',
#  'catch',
#  'cate',
#  'catherin',
#  'cathi',
#  'cathol',
#  'caught',
#  'caus',
#  'cave',
#  'cecilia',
#  'cedric',
#  'celebr',
#  'celest',
#  'celia',
#  'cell',
#  'cem',
#  'cengiz',
#  'center',
#  'central',
#  'centuri',
#  'ceo',
#  'cezmi',
#  'cha',
#  'chad',
#  'chaddha',
#  'chadha',
#  'chain',
#  'chakraborti',
#  'chalk',
#  'challeng',
#  'chamber',
#  'champ',
#  'champion',
#  'championship',
#  'chan',
#  'chanc',
#  'chandan',
#  'chandler',
#  'chang',
#  'chao',
#  'chaotic',
#  'chapman',
#  'chappell',
#  'char',
#  'charact',
#  'charg',
#  'charismat',
#  'charl',
#  'charli',
#  'charlott',
#  'charm',
#  'chart',
#  'chase',
#  'chastain',
#  'chatterje',
#  'chaudhari',
#  'chaudhri',
#  'chauhan',
#  'chawla',
#  'cheadl',
#  'cheat',
#  'cheema',
#  'cheer',
#  'chef',
#  'chelsea',
#  'chen',
#  'cheng',
#  'cherri',
#  'cheryl',
#  'chetan',
#  'cheung',
#  'chhota',
#  'chi',
#  'chia',
#  'chiang',
#  'chiara',
#  'chiba',
#  'chicago',
#  'chicken',
#  'chie',
#  'chief',
#  'chien',
#  'chika',
#  'child',
#  'childhood',
#  'chill',
#  'chin',
#  'china',
#  'chine',
#  'chiu',
#  'chloe',
#  'chloë',
#  'cho',
#  'chocol',
#  'choi',
#  'choic',
#  'chong',
#  'choos',
#  'chopra',
#  'chosen',
#  'chou',
#  'chow',
#  'chris',
#  'christi',
#  'christian',
#  'christin',
#  'christina',
#  'christma',
#  'christoph',
#  'chronicl',
#  'chu',
#  'chuck',
#  'chun',
#  'chung',
#  'church',
#  'cia',
#  'ciara',
#  'cindi',
#  'cinema',
#  'circl',
#  'circumst',
#  'circus',
#  'citi',
#  'citizen',
#  'civil',
#  'civilian',
#  'claim',
#  'clair',
#  'clan',
#  'clara',
#  'clare',
#  'clarenc',
#  'clark',
#  'clarkson',
#  'clash',
#  'class',
#  'classic',
#  'classmat',
#  'claudia',
#  'claudio',
#  'claus',
#  'clayton',
#  'clean',
#  'clear',
#  'clees',
#  'cleo',
#  'clever',
#  'client',
#  'cliff',
#  'climat',
#  'clint',
#  'clive',
#  'clooney',
#  'close',
#  'closer',
#  'club',
#  'clue',
#  'coach',
#  'coast',
#  'coat',
#  'cocain',
#  'coco',
#  'code',
#  'codi',
#  'coffe',
#  'cohen',
#  'cold',
#  'cole',
#  'coleman',
#  'colin',
#  'collaps',
#  'colleagu',
#  'collect',
#  'collector',
#  'colleen',
#  'colleg',
#  'collett',
#  'collid',
#  'collin',
#  'colm',
#  'colman',
#  'colombia',
#  'colombian',
#  'coloni',
#  'color',
#  'coma',
#  'combat',
#  'come',
#  'comeback',
#  'comed',
#  'comedi',
#  'comedian',
#  'comfort',
#  'comic',
#  'command',
#  'commerci',
#  'commit',
#  'common',
#  'communic',
#  'communiti',
#  'compani',
#  'companion',
#  'compel',
#  'compet',
#  'competit',
#  'competitor',
#  'complet',
#  'complex',
#  'complic',
#  'comput',
#  'concert',
#  'condit',
#  'confess',
#  'confid',
#  'confin',
#  'conflict',
#  'confront',
#  'connect',
#  'conni',
#  'connolli',
#  'connor',
#  'conquer',
#  'consequ',
#  'conserv',
#  'consid',
#  'conspiraci',
#  'constanc',
#  'constant',
#  'construct',
#  'contact',
#  'contend',
#  'contest',
#  'continu',
#  'contract',
#  'control',
#  'controversi',
#  'convent',
#  'converg',
#  'convers',
#  'convict',
#  'convinc',
#  'coogan',
#  'cook',
#  'cool',
#  'cooper',
#  'cop',
#  'cope',
#  'corddri',
#  'corey',
#  'cori',
#  'corlett',
#  'corner',
#  'coronado',
#  'corpor',
#  'corrupt',
#  'cost',
#  'costa',
#  'count',
#  'counti',
#  'countri',
#  'coup',
#  'coupl',
#  'courag',
#  'cours',
#  'court',
#  'courtney',
#  'cousin',
#  'cover',
#  'covert',
#  'cowboy',
#  'cowork',
#  'cox',
#  'crack',
#  'craft',
#  'craig',
#  'crash',
#  'crawford',
#  'crazi',
#  'creat',
#  'creation',
#  'creativ',
#  'creator',
#  'creatur',
#  'crew',
#  'cricket',
#  'crime',
#  'crimin',
#  'crisi',
#  'cristina',
#  'critic',
#  'critter',
#  'crook',
#  'cross',
#  'crow',
#  'crowd',
#  'crown',
#  'cruel',
#  'cruis',
#  'crumbl',
#  'crusad',
#  'crush',
#  'cruz',
#  'crystal',
#  'cuba',
#  'cuesta',
#  'cueva',
#  'cuisin',
#  'culinari',
#  'cullen',
#  'cult',
#  'cultur',
#  'cum',
#  'cumberbatch',
#  'cun',
#  'cup',
#  'cur',
#  'cure',
#  'curio',
#  'curious',
#  'current',
#  'curri',
#  ...]

# %%
#converting x to array
df_all= pd.DataFrame(x,columns=tfid.get_feature_names())

# %%
x.shape
# Out:
# (7770, 5000)

# %% [markdown]
# # Principle component analysis for dimensionality reduction

# %% [markdown]
# To find the most important features (also called principal components) that explain the maximum variance in the data

# %%
#defining a pca variable
pca=PCA()
pca1=pca.fit_transform(df_all)

# %%
#plotting the percentage of varience of the matrix by 
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("number of required component")
plt.ylabel("eVR")
# Out:
# Text(0, 0.5, 'eVR')

# %% [markdown]
# **In the selected 5000 components after pca dimensionality reduction we require 3000 components to summarize 90 percent of data**

# %%
#dimensionality reduction after getting to know number of components to summarize
pca=PCA(n_components=3000)
f_pca=pca.fit_transform(df_all)

# %%
f_pca
# Out:
# array([[ 1.57171430e-01, -1.92420930e-02, -2.10109707e-03, ...,
#         -3.94546376e-03, -2.63686080e-03, -3.06159791e-04],
#        [-4.65806416e-02, -2.37233781e-02,  1.99431660e-02, ...,
#          1.30542137e-02, -1.31948734e-02, -2.11611384e-03],
#        [-4.76446634e-02, -4.77347880e-02, -3.43519249e-03, ...,
#          6.46657657e-03,  7.37919802e-03,  1.35711237e-03],
#        ...,
#        [-1.30369978e-01,  2.50611125e-01,  1.56310891e-01, ...,
#         -8.57847548e-03, -2.67364918e-03, -1.06467476e-03],
#        [ 1.48560459e-01,  2.71066276e-02,  1.16464058e-02, ...,
#          9.46860177e-03, -1.08518047e-02, -1.37041305e-02],
#        [-1.12753137e-01,  3.56274358e-01,  1.10149889e-01, ...,
#         -5.92321339e-03, -3.66024824e-03, -3.33968770e-03]])

# %% [markdown]
# *  The most important features that explain the majority of the variance in the data can be identified.
# * The reduced set of principal components can be used to visualize the data and identify patterns and relationships.
# * The new reduced dataset can be used for further analysis and modeling.

# %%
y_df=pd.DataFrame(f_pca)

# %%
y_df.describe()
# Out:
#                0             1             2             3             4     \
# count  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03
# mean   8.184501e-17  5.142462e-17 -3.486415e-17  4.103682e-17 -1.417428e-17
# std    9.772580e-02  7.706113e-02  6.905516e-02  6.481308e-02  6.037110e-02
# min   -1.542422e-01 -1.281594e-01 -2.186440e-01 -1.919013e-01 -2.005380e-01
# 25%   -6.296316e-02 -4.531971e-02 -5.229186e-02 -3.213885e-02 -3.395092e-02
# 50%   -4.603715e-02 -2.475860e-02 -4.575329e-03 -8.743901e-03 -1.254228e-03
# 75%    5.241029e-02  7.967355e-03  4.693232e-02  1.414895e-02  2.775029e-02
# max    3.758146e-01  3.859974e-01  2.938281e-01  4.951903e-01  3.911947e-01
#
#                5             6             7             8             9     \
# count  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03
# mean   2.743408e-18 -5.315353e-18 -2.617669e-17 -9.430466e-19 -8.858922e-18
# std    5.820647e-02  5.535091e-02  5.281045e-02  5.157967e-02  4.927105e-02
# min   -1.967330e-01 -1.971080e-01 -2.229254e-01 -1.645873e-01 -2.232074e-01
# 25%   -2.684167e-02 -3.053331e-02 -3.330754e-02 -3.036194e-02 -2.954059e-02
# 50%   -5.473043e-03  3.574538e-03 -4.226832e-03 -2.380879e-03 -9.230748e-04
# 75%    1.907413e-02  3.404555e-02  2.939631e-02  2.176578e-02  2.903534e-02
# max    5.026118e-01  2.315381e-01  3.193246e-01  3.451143e-01  2.372231e-01
#
#        ...          2990          2991          2992          2993  \
# count  ...  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03
# mean   ... -1.051104e-16 -3.433190e-17 -8.366681e-17  6.285548e-17
# std    ...  8.139088e-03  8.135613e-03  8.129531e-03  8.105506e-03
# min    ... -3.355711e-02 -3.297020e-02 -3.267844e-02 -3.197797e-02
# 25%    ... -5.432410e-03 -5.494561e-03 -5.464318e-03 -5.334638e-03
# 50%    ... -3.479164e-05 -5.350179e-05 -1.113027e-04 -6.452289e-06
# 75%    ...  5.393507e-03  5.299973e-03  5.352839e-03  5.332433e-03
# max    ...  3.374142e-02  3.313286e-02  3.347000e-02  3.473026e-02
#
#                2994          2995          2996          2997          2998  \
# count  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03
# mean   1.375741e-16 -2.613382e-17 -1.721774e-18 -1.355272e-16  9.774285e-17
# std    8.100505e-03  8.092167e-03  8.086824e-03  8.074197e-03  8.068011e-03
# min   -3.286209e-02 -3.014547e-02 -3.092123e-02 -3.241439e-02 -3.499958e-02
# 25%   -5.408433e-03 -5.495668e-03 -5.511813e-03 -5.376083e-03 -5.374650e-03
# 50%   -3.617129e-05 -2.204374e-05 -3.315233e-05  4.700453e-05 -1.116210e-04
# 75%    5.443546e-03  5.421440e-03  5.447469e-03  5.431003e-03  5.364848e-03
# max    3.348757e-02  3.291477e-02  3.856017e-02  3.564384e-02  3.995580e-02
#
#                2999
# count  7.770000e+03
# mean  -3.890782e-17
# std    8.058516e-03
# min   -2.943104e-02
# 25%   -5.379890e-03
# 50%    2.685194e-05
# 75%    5.278878e-03
# max    3.122856e-02
#
# [8 rows x 3000 columns]

# %% [markdown]
# # ML Model Implementation

# %% [markdown]
# # KMeans Clustering

# %%
#scaling the data
scalar=StandardScaler()
rescaled=scalar.fit_transform(y_df)
scaled_values=rescaled

# %%
df2=pd.DataFrame(scaled_values)

# %%
df2.describe()
# Out:
#                0             1             2             3             4     \
# count  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03
# mean  -1.097363e-17 -3.474984e-17 -4.023665e-17 -1.353415e-16  2.560514e-17
# std    1.000064e+00  1.000064e+00  1.000064e+00  1.000064e+00  1.000064e+00
# min   -1.578418e+00 -1.663195e+00 -3.166426e+00 -2.961032e+00 -3.321968e+00
# 25%   -6.443254e-01 -5.881386e-01 -7.572964e-01 -4.959017e-01 -5.624066e-01
# 50%   -4.711153e-01 -3.213059e-01 -6.626042e-02 -1.349182e-01 -2.077664e-02
# 75%    5.363339e-01  1.033967e-01  6.796790e-01  2.183180e-01  4.596914e-01
# max    3.845850e+00  5.009299e+00  4.255251e+00  7.640776e+00  6.480251e+00
#
#                5             6             7             8             9     \
# count  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03
# mean   3.292090e-17 -2.560514e-17 -4.755241e-17 -7.315755e-18  8.596013e-17
# std    1.000064e+00  1.000064e+00  1.000064e+00  1.000064e+00  1.000064e+00
# min   -3.380134e+00 -3.561291e+00 -4.221509e+00 -3.191139e+00 -4.530485e+00
# 25%   -4.611755e-01 -5.516672e-01 -6.307405e-01 -5.886795e-01 -5.995913e-01
# 50%   -9.403413e-02  6.458373e-02 -8.004295e-02 -4.616223e-02 -1.873583e-02
# 75%    3.277188e-01  6.151254e-01  5.566740e-01  4.220108e-01  5.893362e-01
# max    8.635537e+00  4.183365e+00  6.047007e+00  6.691328e+00  4.814965e+00
#
#        ...          2990          2991          2992          2993  \
# count  ...  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03
# mean   ...  1.051640e-17 -5.944051e-18 -3.017749e-17 -5.486816e-18
# std    ...  1.000064e+00  1.000064e+00  1.000064e+00  1.000064e+00
# min    ... -4.123222e+00 -4.052839e+00 -4.019979e+00 -3.945470e+00
# 25%    ... -6.674899e-01 -6.754150e-01 -6.721999e-01 -6.581923e-01
# 50%    ... -4.274911e-03 -6.576669e-03 -1.369204e-02 -7.960890e-04
# 75%    ...  6.627098e-01  6.514954e-01  6.584861e-01  6.579203e-01
# max    ...  4.145869e+00  4.072833e+00  4.117353e+00  4.285049e+00
#
#                2994          2995          2996          2997          2998  \
# count  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03  7.770000e+03
# mean   7.315755e-18  1.097363e-17  5.486816e-18 -1.988971e-17  2.011833e-17
# std    1.000064e+00  1.000064e+00  1.000064e+00  1.000064e+00  1.000064e+00
# min   -4.057056e+00 -3.725504e+00 -3.823902e+00 -4.014823e+00 -4.338348e+00
# 25%   -6.677091e-01 -6.791780e-01 -6.816234e-01 -6.658779e-01 -6.662108e-01
# 50%   -4.465600e-03 -2.724259e-03 -4.099813e-03  5.821948e-03 -1.383590e-02
# 75%    6.720440e-01  6.700046e-01  6.736662e-01  6.726802e-01  6.649957e-01
# max    4.134276e+00  4.067747e+00  4.768578e+00  4.414822e+00  4.952692e+00
#
#                2999
# count  7.770000e+03
# mean   3.474984e-17
# std    1.000064e+00
# min   -3.652401e+00
# 25%   -6.676460e-01
# 50%    3.332335e-03
# 75%    6.551104e-01
# max    3.875474e+00
#
# [8 rows x 3000 columns]

# %% [markdown]
# **Elbow method to find the number of clusters**

# %%
#Implementaing kmeans clustering
#considering range of 10 clusters

silhoutte_score=[]
value=[]
range=np.arange(1,15)
for i in range:
  kmeans=KMeans(n_clusters=i,init='k-means++',random_state=30)
  preds=kmeans.fit(f_pca)
  pred_values=preds.inertia_
  value.append(pred_values)


plt.figure(figsize=(12,10))
plt.plot(range,value)
plt.xlabel('optimal k')
plt.ylabel('sum of squared distances')
# Out:
# Text(0, 0.5, 'sum of squared distances')

# %% [markdown]
# **By plotting the optimal k by using Elbow method there are 7 clusters which are optimal**

# %%
#applying kmeans after knowing number of clusters 
kmean1= KMeans(n_clusters=7 ,init = 'k-means++' , random_state=30)
labels=kmean1.fit_predict(y_df)

# %%
y_df['cluster_number']=labels

# %%
#componenets present in each cluster
y_df['cluster_number'].value_counts()
# Out:
# 4    2363
# 0    2025
# 2    1792
# 1     707
# 6     378
# 3     335
# 5     170
# Name: cluster_number, dtype: int64

# %%
y_df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.157171 -0.019242 -0.002101  0.001361 -0.046245 -0.009440 -0.011058
# 1    -0.046581 -0.023723  0.019943 -0.026157  0.001194 -0.006948 -0.005729
# 2    -0.047645 -0.047735 -0.003435 -0.039787 -0.044303  0.059706 -0.001708
# 3    -0.059854 -0.048335 -0.121134 -0.018272 -0.125009  0.044003 -0.059949
# 4    -0.033125 -0.023857 -0.060975  0.004633 -0.007856  0.013929  0.007709
# ...        ...       ...       ...       ...       ...       ...       ...
# 7765 -0.061825 -0.039790  0.021902 -0.044685 -0.011281 -0.014026  0.047249
# 7766 -0.103854  0.055194  0.156886  0.288187 -0.131840 -0.054355  0.044750
# 7767 -0.130370  0.250611  0.156311  0.200909 -0.078263  0.029373 -0.015291
# 7768  0.148560  0.027107  0.011646  0.002699  0.012879 -0.033792  0.018361
# 7769 -0.112753  0.356274  0.110150  0.211104 -0.092752  0.035371  0.024419
#
#              7         8         9  ...      2991      2992      2993  \
# 0    -0.009718 -0.053567 -0.005856  ...  0.005010 -0.006129  0.005853
# 1    -0.018323  0.000677 -0.010568  ...  0.002841 -0.010251  0.015052
# 2    -0.018652  0.053553  0.009601  ... -0.009509  0.004028  0.007815
# 3     0.013742 -0.031400  0.083738  ...  0.012437 -0.009311  0.018253
# 4    -0.055873 -0.001394  0.033720  ...  0.007637  0.004375 -0.007597
# ...        ...       ...       ...  ...       ...       ...       ...
# 7765  0.024127  0.008777 -0.077621  ...  0.015317 -0.001729 -0.001758
# 7766  0.008294  0.054404 -0.039484  ... -0.003283  0.001122  0.007698
# 7767 -0.040023 -0.035491 -0.002786  ...  0.004423 -0.006173  0.001038
# 7768  0.011833 -0.035926 -0.000388  ... -0.001009  0.002554 -0.010199
# 7769 -0.008140 -0.031692 -0.011499  ...  0.015644 -0.003569 -0.003173
#
#           2994      2995      2996      2997      2998      2999  \
# 0     0.007203 -0.007204  0.000246 -0.003945 -0.002637 -0.000306
# 1     0.015384  0.004879  0.009721  0.013054 -0.013195 -0.002116
# 2     0.005739 -0.008645  0.007483  0.006467  0.007379  0.001357
# 3     0.017829  0.004000 -0.006655  0.001787  0.006028 -0.001472
# 4     0.012849  0.001417 -0.008033  0.003404  0.002042 -0.002087
# ...        ...       ...       ...       ...       ...       ...
# 7765 -0.005326 -0.021189  0.005535  0.010464 -0.021718  0.012319
# 7766  0.000562 -0.005223 -0.000399 -0.007810  0.001556  0.008043
# 7767  0.002542 -0.010181 -0.004318 -0.008578 -0.002674 -0.001065
# 7768 -0.004640 -0.000591 -0.012222  0.009469 -0.010852 -0.013704
# 7769 -0.005449 -0.013823  0.002306 -0.005923 -0.003660 -0.003340
#
#       cluster_number
# 0                  2
# 1                  0
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 7765               0
# 7766               3
# 7767               3
# 7768               2
# 7769               3
#
# [7770 rows x 3001 columns]

# %%
#silhouette method to find the optimal clusters
#range=np.arange(1,20)
silhoutte_score=[]
value=[]
range=np.arange(2,8)
for i in range:
  kmeans=KMeans(n_clusters=i,init='k-means++',random_state=33)
  preds=kmeans.fit(y_df)
  pred_values=preds.labels_
  sil_score=silhouette_score(y_df,pred_values, metric='euclidean')
  silhoutte_score.append(silhouette_score(y_df,pred_values, metric='euclidean'))
  silhouette_values = silhouette_samples(f_pca, pred_values)
  print('for n_clusters: ', i)
  #for value in score:
  print('silhouette_score is: {}'.format(sil_score))

#plotting the graph for all the values
plt.plot(range,silhoutte_score,color='red')
plt.xlabel('number of clusters')
plt.ylabel('silhoutte score')
plt.title('clusters vs silhoutte score' )
plt.show()
# Out:
# for n_clusters:  2
# silhouette_score is: 0.48200894277210904
# for n_clusters:  3
# silhouette_score is: 0.3557165658500276
# for n_clusters:  4
# silhouette_score is: 0.3365541775949554
# for n_clusters:  5
# silhouette_score is: 0.2531145632898742
# for n_clusters:  6
# silhouette_score is: 0.21283828383539755
# for n_clusters:  7
# silhouette_score is: 0.2074649462141611

# %%
#for n_cluster in range:
colors = cm.nipy_spectral(pred_values.astype(float) /7)
plt.figure(figsize = (16,6))
sns.set_style('white')
sns.scatterplot(f_pca[:,0],f_pca[:,1],c=colors)
plt.ylabel('PC2')
plt.xlabel('PC1')
# Out:
# Text(0.5, 0, 'PC1')

# %% [markdown]
# *   Based on the given information, the silhouette score for clustering is highest when there are 2 clusters with a value of 0.534
# *   Cluster 4 has the highest text  values
#
#
# *   Additionally, the statement suggests that as the number of clusters increases, the silhouette score tends to decrease, indicating that the quality of the clusters decreases as the number of clusters increases.

# %% [markdown]
# # Heirarchical clustering

# %% [markdown]
# Choosing the number of clusters using dendrogram

# %%
#plotting the dendrogram plot to find the clusters
plt.figure(figsize=(15,10))
shc.dendrogram((shc.linkage(f_pca, method ='ward')))
plt.title('dendogram')
plt.xlabel('labels')
plt.ylabel('euclidean distance')
# Out:
# Text(0, 0.5, 'euclidean distance')

# %% [markdown]
# **By identifying the vertical line with the greatest distance between two lines, at a distance of 6, it is possible to draw a horizontal line that will result in 4 distinct clusters**

# %%
#plotting the dendrogram with known clusters and marking a horizontal line for the longest vertical distance
plt.figure(figsize=(15,10))
shc.dendrogram((shc.linkage(f_pca, method ='ward')))
plt.axhline(y=6, color='r', linestyle='--')
plt.title('dendogram')
plt.xlabel('labels')
plt.ylabel('euclidean distance')
# Out:
# Text(0, 0.5, 'euclidean distance')

# %% [markdown]
# **Number of clusters are 4**

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 6, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(f_pca)

# %%
#silhouette score for each cluster
range=np.arange(2,7)
silhoutte_score=[]
for i in range:
 hierarchical = AgglomerativeClustering(n_clusters=i, affinity='euclidean', linkage='ward')  
 hierarchical.fit(y_df)
 hc=hierarchical.fit_predict(y_df)
 lab=hierarchical.labels_
 silhoutte_score.append(silhouette_score(y_df,lab, metric='euclidean'))
 sil_score=silhouette_score(y_df,lab, metric='euclidean')
 print('for n_clusters: ', i)
  #for value in score:
 print('silhouette_score is: {}'.format(sil_score))

#plotting the graph for all the values
plt.plot(range,silhoutte_score,color='red')
plt.xlabel('number of clusters')
plt.ylabel('silhoutte score')
plt.title('clusters vs silhoutte score' )
plt.show()
# Out:
# for n_clusters:  2
# silhouette_score is: 0.4643677229624819
# for n_clusters:  3
# silhouette_score is: 0.35556181873739007
# for n_clusters:  4
# silhouette_score is: 0.3514302106457645
# for n_clusters:  5
# silhouette_score is: 0.253120281890955
# for n_clusters:  6
# silhouette_score is: 0.212791579735758

# %% [markdown]
# * Silhouette score is indicative of better clustering results, suggesting well-separated and distinct clusters.
# * It's important to compare the silhouette scores of different clustering algorithms and parameter settings to determine which one is the most appropriate for the given dataset.
# * The cluster with the highest silhouette score of 0.517 is cluster 2, indicating that the data points within this cluster are well-separated and distinct compared to the other clusters

# %% [markdown]
# # DBSCAN

# %% [markdown]
# DBSCAN (Density-Based Spatial Clustering of Applications with Noise) is a popular clustering algorithm that groups together data points that are close to each other in a high-density region and separates out data points that are in low-density regions.

# %%
#plotting the dbscan plot to check the purity of the cluster 
db=DBSCAN(eps=0.3,min_samples=20)
db_pred=db.fit_predict(scaled_values)
plt.figure(figsize=( 8 , 5 ))
plt.scatter(y=f_pca[:,0],x= f_pca[:,1], c=db_pred)

# %%
#finding all the labels
label=db.labels_

# %%
label
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %% [markdown]
# Observations from Dbscan:
#
# *   The data labels are too tightly packed to form distinct clusters using the DBSCAN clustering algorithm.
# *   Additionally, a label with a value of -1 indicates that the data point is considered an outlier or noise and cannot be assigned to any specific cluster.

# %% [markdown]
# # conclusion

# %% [markdown]
# *  There are 69% of movie content and 31% of Tv show content in netflix
# *  Content of top 10 countries accounts for 69.54% for overall contents present
# *   United Nations has highest movie content released and then followed by India
# *   United Nations has highest tv show content released and then followed by United Kingdom
# *   Netflix started releasing movies after 1940 and after 1980 Tv show content was started streaming.
# *   There is a graduall increase in releases after 2000 where movie content releases are more then Tv show content
#
#
# *    In the month of january, october and december maximum movies/tvshows has been released.
# *   Black Mirror: Bandersnatch is the longest movie and Grey's Anatomy is longest Tv show
#
#
# *   Movies which are documentaries and stand up comedy has highest content in netflix and Tv shows for kids category has highest content in netflix
#
# *   Most of the contents got rating TV_MA(Mature Audience)
#
#
# *   After vectorizing text data by using TFIDF and pca dimensionality reduction we require 1500 components to summarize 90 percent of data
# *   In k-means clustering Elbow method is used to find the number of optimal clusters and there are 10 clusters after applying kmeans clustering
#
#
# *   To measure the quality of clusters and how well the clusters are separated, silhoutte score is considered.
# *   In K-Means clustering the sihoutte score is highest for cluster 2 and the score is 0.534
#
#
# *   In hierarchical clustering dendrogram plot is used to find the optimal clusters and the number of clusters came out to be 4
#
#
# *   The silhoutte score for hierarchical cluster is highest for cluster 2 and the silhouette_score is 0.517
# *   By applying kmeans and hierarchical we got the best clusters and optimal cluster equal to 2
